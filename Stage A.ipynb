# %%
import pandas as pd
import numpy as np

# %%
 df=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding= "latin-1")
 df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
#Question 1
#How would you check for the number of rows and columns in a pandas DataFrame named df?
df.shape
# Out:
# (60943, 12)

# %%
#Question 2
#What is the total number of unique countries in the dataset?
df['Area'].nunique()
# Out:
# 49

# %%
#Question 3
#Which year had the least correlation with ‘Element Code’?
df.corr()
# Out:
# <ipython-input-77-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
#Question 4
#Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?
DF=df.groupby('Element').sum()
DF.loc['Stock Variation']
# Out:
# <ipython-input-79-6987d5568744>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   DF=df.groupby('Element').sum()
# Area Code         571566.00
# Item Code       11329527.00
# Element Code    21464704.00
# Y2014              58749.83
# Y2015              34910.99
# Y2016              33140.12
# Y2017              54316.91
# Y2018              20577.91
# Name: Stock Variation, dtype: float64

# %%
#Question 5
#Consider the following list of tuples:
#y = [(2, 4), (7, 8), (1, 5, 9)]
#How would you assign element 8 from the list to a variable x?

y = [(2, 4), (7, 8), (1, 5, 9)]
y[1][1]
# Out:
# 8

# %%
#Question 7
#Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?
DF=df.groupby('Element').sum()
DF.loc['Processing']
# Out:
# <ipython-input-18-2efc148cab91>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   DF=df.groupby('Element').sum()
# Area Code         271940.0
# Item Code        5350416.0
# Element Code    10313310.0
# Y2014             282923.0
# Y2015             287929.0
# Y2016             280631.0
# Y2017             292836.0
# Y2018             308429.0
# Name: Processing, dtype: float64

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ce1543b3be47> in <cell line: 3>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
 df[['Y2017','Area']].groupby('Area').sum().sort_values('Y2017', ascending=False).head()
# Out:
#                    Y2017
# Area
# Nigeria       1483268.23
# Egypt          866379.92
# South Africa   517590.54
# Ethiopia       448683.76
# Morocco        388495.36

# %%
#Question 11
#What is the total Protein supply quantity in Madagascar in 2015?

mad=df[df['Area']=='Madagascar']
mad=mad.groupby('Element').sum()
mad.loc['Protein supply quantity (g/capita/day)', 'Y2015']
# Out:
# <ipython-input-38-92f52cbf8ff3>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mad=mad.groupby('Element').sum()
# 173.05

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']
pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
#Question 13
#Answer the following questions based on the African food production dataset provided by the FAO website already provided
#What is the total sum of Wine produced in 2015 and 2018 respectively?
#Hint:
#Perform a groupby sum aggregation on ‘Item’
print(df.groupby('Item').sum().loc['Wine','Y2015'])
print(df.groupby('Item').sum().loc['Wine','Y2018'])
# Out:
# 4251.81
# 4039.32
# <ipython-input-57-32ffcccbaf76>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('Item').sum().loc['Wine','Y2015'])
# <ipython-input-57-32ffcccbaf76>:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print(df.groupby('Item').sum().loc['Wine','Y2018'])

# %%
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?
lw=df[['Y2017','Area']].groupby('Area').sum().sort_values('Y2017',ascending=True)
lw.iloc[6]
# Out:
# Y2017    19102.77
# Name: Guinea-Bissau, dtype: float64

# %%
#What is the total number and percentage of missing data in 2014 to 3 decimal places?
print(df['Y2014'].isnull().sum())
print(round(df['Y2014'].isnull().sum()/len(df['Y2014']),3))
# Out:
# 1589
# 0.026

# %%
#What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?
print(df['Y2017'].mean())
print(df['Y2017'].std())
# Out:
# 140.9177648602722
# 1671.8623590567995

# %%
#What would be the output for?
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
#Question 8
#Given the following numpy array
#array  = ([[94, 89, 63],[93, 92, 48],[92, 94, 56]])
#How would you select  the elements in bold and italics from the array?
array  = ([[94, 89, 63],[93, 92, 48],[92, 94, 56]])
array[:2, 1:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-9ec3dd748bee> in <cell line: 6>()
#       4 #How would you select  the elements in bold and italics from the array?
#       5 array  = ([[94, 89, 63],[93, 92, 48],[92, 94, 56]])
# ----> 6 array[:2, 1:]
#
# TypeError: list indices must be integers or slices, not tuple
